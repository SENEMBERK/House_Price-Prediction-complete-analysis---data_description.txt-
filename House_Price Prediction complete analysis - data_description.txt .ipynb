# %%
#IMPORT THE LIBRARIES....
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
# %matplotlib inline
import seaborn as sns
import matplotlib
from datetime import date
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df = pd.read_csv('train.csv')
df1 = pd.read_csv('test.csv')
df2 = pd.read_csv('test.csv')

# %%
print("shape of training data:",train.shape)
print("shape of testing data:",test.shape)
# Out:
# shape of training data: (1460, 81)
# shape of testing data: (1459, 80)

# %%
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# **Sayısal Özellikler**

# %%
numerical_feature = [feature for feature in train.columns if train[feature].dtype != 'O']

print("len of numerical_feature",len(numerical_feature))
# Out:
# len of numerical_feature 38

# %%
## 38 sayısal özellik var , yıllık kayıtlar farklı olabiir ve zamana göre değişen bir tür ilişkiye sahip olabilir.

# %%
df[numerical_feature].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
df[numerical_feature].dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %%
test_numeric = [feature for feature in test.columns if test[feature].dtype != 'O']
print("len of numeric feature in test data",len(test_numeric))
# Out:
# len of numeric feature in test data 37

# %%
test[test_numeric].isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      227
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea        15
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       2
# BsmtHalfBath       2
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       78
# GarageCars         1
# GarageArea         1
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
for feature in test_numeric:
    test[feature] = test[feature].fillna(test[feature].median())

# %%
test[test_numeric].isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# dtype: int64

# %% [markdown]
# Temporical variables

# %%
**Geçici değişken, bir tarih saat olan bir zaman aralığından sonra verilerin değiştiği değişkenlerdir. 
  evlerin fiyatları artıyor ya da artmıyor.**

# %%
### datetime değişkenlerinin saleprice ile ilişkisini kontrol edeceğiz

# %%
year_feature = [feature for feature in numerical_feature if 'Yr' in feature or 'Year' in feature]

print("len of year feature",len(year_feature))
# Out:
# len of year feature 4

# %%
df[year_feature].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0       2003          2003       2003.0    2008
# 1       1976          1976       1976.0    2007
# 2       2001          2002       2001.0    2008
# 3       1915          1970       1998.0    2006
# 4       2000          2000       2000.0    2008

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Satış fiyatına karşılık gelen yılı göreceğiz..

# %%
plt.bar(train['YrSold'],train['SalePrice'])
plt.show()

# %%
df.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel("year sold")
plt.ylabel("saleprice")
plt.title("YearSold Vs SalePrice")
plt.xticks(rotation=45)
plt.show()

# %%
## Mülk fiyatı düşüş görünüyor..

# %%
for feature in year_feature:
    if feature != 'YrSold':
        data = df.copy()
        
        data[feature] = data['YrSold'] - data[feature]
        
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel("SalePrice")
        plt.title(feature + " Vs SalePrice")
        plt.show()

# %%
## YearBuilt ile saleprice arasında çok fark yok, salePrice uzun yıllar sabit kaldığı için yıldaki artışı yok..

# %%
**Sayısal özelliklerde Eksik değerlerin ele alınması

# %%
df[year_feature].isna().sum()
# Out:
# YearBuilt        0
# YearRemodAdd     0
# GarageYrBlt     81
# YrSold           0
# dtype: int64

# %%
df['GarageYrBlt'].fillna(train['GarageYrBlt'].median(),inplace=True)

# %%
numerics_with_nan = [feature for feature in df.columns if df[feature].isna().sum()>1 and df[feature].dtype != 'O']

for feature in numerics_with_nan:
    print(feature," perc_miss:",np.round(df[feature].isna().mean(),3))
# Out:
# LotFrontage  perc_miss: 0.177
# MasVnrArea  perc_miss: 0.005

# %%
for feature in numerics_with_nan:
    median_val = df[feature].median()
    
    df[feature].fillna(median_val,inplace=True)

# %%
df[numerics_with_nan].isna().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# dtype: int64

# %%
**Ayrık özelliklere..

# %%
discrete_feature = [feature for feature in numerical_feature if len(df[feature].unique())<25 and feature not in year_feature + ['Id'] ]

print("len of discrete_feature",len(discrete_feature))
# Out:
# len of discrete_feature 17

# %%
df[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
## Ayrık özelliğin hedef satış fiyatınızla ilişkisini görelim ..

# %%
for feature in discrete_feature:
    df.groupby(feature)['SalePrice'].median().plot(kind='bar')
    plt.xlabel(feature)
    plt.ylabel("SalePrice")
    plt.title(feature)
    plt.show()

# %%
## OverQual, SalePrice ile olumlu bir ilişki olarak görülebilir..

# %%
**Sürekli Özellikler

# %%
continuous_feature = [feature for feature in numerical_feature if feature not in discrete_feature + year_feature + ['Id']]

print("len of continuous feature",len(continuous_feature))
# Out:
# len of continuous feature 16

# %%
df[continuous_feature].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710         548           0
# 1         1262      1262         0       1262         460         298
# 2          920       920       866       1786         608           0
# 3          756       961       756       1717         642           0
# 4         1145      1145      1053       2198         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  SalePrice
# 0           61              0            0     208500
# ...

# %%
df[continuous_feature].isna().sum()
# Out:
# LotFrontage      0
# LotArea          0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# GrLivArea        0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# ScreenPorch      0
# SalePrice        0
# dtype: int64

# %%
## Sayısal özelliklerin hiçbirinde eksik değer yoktur ..

# %%
for feature in continuous_feature:
    data = df.copy()
    data.hist(column=feature,bins=40)
    plt.title(feature + ' Vs SalePrice')
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.show()

# %%
** Aykırı değerler**

# %%
for feature in continuous_feature:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        sns.boxplot(data[feature])
        plt.title(feature)
        plt.show()

# %%
for feature in continuous_feature:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data['SalePrice'] = np.log(data['SalePrice'])
        plt.scatter(data[feature],data['SalePrice'])
        plt.title(feature + ' Vs SalePrice')
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
## Farklılık görünüyor, belirli bir aralığa getirerek aykırı değerleri kaldırabiliriz. bunu IQR yardımıyla ve alt ve üst sınırı hesaplayarak yapabiliriz.

# %%
df[numerical_feature].corr()['SalePrice'][:-1].sort_values(ascending=False).to_frame()
# Out:
#                SalePrice
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# MasVnrArea      0.472614
# Fireplaces      0.466929
# GarageYrBlt     0.466754
# BsmtFinSF1      0.386420
# LotFrontage     0.334771
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# BsmtFullBath    0.227122
# BsmtUnfSF       0.214479
# BedroomAbvGr    0.168213
# ScreenPorch     0.111447
# PoolArea        0.092404
# MoSold          0.046432
# 3SsnPorch       0.044584
# BsmtFinSF2     -0.011378
# BsmtHalfBath   -0.016844
# MiscVal        -0.021190
# Id             -0.021917
# LowQualFinSF   -0.025606
# YrSold         -0.028923
# OverallCond    -0.077856
# MSSubClass     -0.084284
# EnclosedPorch  -0.128578
# ...

# %%
### Rapor..

#GeneralQual & GrLivArea, salePrice ile güçlü bir pozitif ilişkiye sahiptir.
#GarageCars & GarageArea ayrıca, park alanı olan evin fiyatının çok daha fazla olması nedeniyle olumlu bir ilişkiye sahiptir.
#KitchenAbvGr'nin negatif bir ilişkisi var

# %% [markdown]
# **Kategorik Özellikler**

# %%
categorical_feature = [feature for feature in train.columns if train[feature].dtype == 'O']

print("len of categorical_feature",len(categorical_feature))
# Out:
# len of categorical_feature 43

# %%
df[categorical_feature].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
categories_with_nan = [feature for feature in categorical_feature if df[feature].isna().sum() > 1]
print(len(categories_with_nan))
# Out:
# 15

# %%
for feature in categories_with_nan:
    print(feature,' count of null:',df[feature].isna().sum())
# Out:
# Alley  count of null: 1369
# MasVnrType  count of null: 8
# BsmtQual  count of null: 37
# BsmtCond  count of null: 37
# BsmtExposure  count of null: 38
# BsmtFinType1  count of null: 37
# BsmtFinType2  count of null: 38
# FireplaceQu  count of null: 690
# GarageType  count of null: 81
# GarageFinish  count of null: 81
# GarageQual  count of null: 81
# GarageCond  count of null: 81
# PoolQC  count of null: 1453
# Fence  count of null: 1179
# MiscFeature  count of null: 1406

# %%
## Eksik değeri %30'dan büyük olan özellik onları düşürür ve 1460 satır olduğu ve 100'den az olduğu için ,
## Eksik değerin yerine sık oluşan kategori ataması olarak bilinen basit tekniği kullanarak dış eksik değerleri empoze etmeye çalışır.

# %%
feature_todrop = [feature for feature in categorical_feature if df[feature].isnull().mean() > 0.3]
feature_todrop
# Out:
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
train.drop(feature_todrop,axis=1,inplace=True)
test.drop(feature_todrop,axis=1,inplace=True)

# %%
## istenmeyen  özellikleri bıraktık..

# %%
df['GarageQual'].value_counts()
# Out:
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64

# %%
feature_toimpute = [feature for feature in train.columns if train[feature].isnull().mean() < 0.30 and df[feature].dtype=='O']
len(feature_toimpute)
# Out:
# 38

# %%
def impute_nan(train,variable):
    most_frequent_category = df[variable].value_counts().index[0]
    df[variable].fillna(most_frequent_category,inplace=True)

# %%
## NAN değerlerini atalım ..

# %%
for feature in feature_toimpute:
    impute_nan(df,feature)

# %%
##  Nan ile birlikte tüm özellikler (Sayısal ve Kategorik) en iyi şekilde hesaplanır ve veriler temizlenir ve daha fazla analiz ve özellik seçimi bölümü için hazırdır.

# %%
plt.figure(figsize=(20,20))
corr = df.corr()
sns.heatmap(corr,vmax=0.9,annot=True)
plt.show()

# %%
df.drop('Id',axis=1,inplace=True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %%
** Kategorik Özelliklerin İşlenmesi**

# %%
categorical_feature = [feature for feature in df.columns if df[feature].dtype == 'O']

print("len of categorical_feature",len(categorical_feature))
# Out:
# len of categorical_feature 43

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for c in categorical_feature:
    lb = LabelEncoder()
    lb.fit(list(df[c].values))
    df[c] = lb.transform(list(df[c].values))

# %%
test_category = [feature for feature in test.columns if test[feature].dtype == 'O']
print("len of category_feature in test data",len(test_category))
# Out:
# len of category_feature in test data 38

# %%
for c in test_category:
    lb = LabelEncoder()
    lb.fit(list(test[c].values))
    test[c] = lb.transform(list(test[c].values))

# %%
df[categorical_feature].head()
# Out:
#    MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0         3       1      2         3            3          0          4
# 1         3       1      2         3            3          0          2
# 2         3       1      2         0            3          0          4
# 3         3       1      2         0            3          0          0
# 4         3       1      2         0            3          0          2
#
#    LandSlope  Neighborhood  Condition1  Condition2  BldgType  HouseStyle  \
# 0          0             5           2           2         0           5
# 1          0            24           1           2         0           2
# 2          0             5           2           2         0           5
# 3          0             6           2           2         0           5
# 4          0            15           2           2         0           5
#
#    RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrType  ExterQual  \
# ...

# %%
test[test_category].head()
# Out:
#    MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 0         2       1         3            3          0          4          0
# 1         3       1         0            3          0          0          0
# 2         3       1         0            3          0          4          0
# 3         3       1         0            3          0          4          0
# 4         3       1         0            1          0          4          0
#
#    Neighborhood  Condition1  Condition2  BldgType  HouseStyle  RoofStyle  \
# 0            12           1           2         0           2          1
# 1            12           2           2         0           2          3
# 2             8           2           2         0           4          1
# 3             8           2           2         0           4          1
# 4            22           2           2         4           2          1
#
# ...

# %%
print(train.shape)
print(test.shape)
# Out:
# (1460, 76)
# (1459, 75)

# %%
x = train.iloc[:,:-1].values
y = train['SalePrice']

# %%
test_x = test.drop('Id',axis=1).values
test_x.shape
# Out:
# (1459, 74)
